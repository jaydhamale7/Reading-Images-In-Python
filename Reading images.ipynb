# %% [markdown]
# ### PILLOW
#
# ##### pip install pillow

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
img = Image.open("./Virat.jpg")

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1038 at 0x171CD6E7988>

# %%
img.show()

# %%
img.format
# Out:
# 'JPEG'

# %%
img = np.asarray(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Matplotlib

# %%
from matplotlib import image

# %%
img = image.imread('./Virat.jpg')

# %%
img
# Out:
# array([[[32, 47, 52],
#         [32, 47, 52],
#         [32, 47, 52],
#         ...,
#         [38, 57, 64],
#         [38, 57, 64],
#         [38, 57, 64]],
#
#        [[32, 47, 52],
#         [32, 47, 52],
#         [32, 47, 52],
#         ...,
#         [38, 57, 64],
#         [38, 57, 64],
#         [38, 57, 64]],
#
#        [[33, 48, 53],
#         [33, 48, 53],
#         [33, 48, 53],
#         ...,
#         [38, 57, 64],
#         [37, 56, 63],
#         [37, 56, 63]],
#
#        ...,
#
#        [[15, 20, 26],
#         [15, 20, 26],
#         [15, 20, 26],
#         ...,
#         [19, 24, 28],
#         [19, 24, 28],
#         [19, 24, 28]],
#
#        [[15, 20, 26],
#         [15, 20, 26],
#         [15, 20, 26],
#         ...,
#         [19, 24, 28],
#         [19, 24, 28],
#         [19, 24, 28]],
#
#        [[15, 20, 26],
#         [15, 20, 26],
#         [15, 20, 26],
#         ...,
#         [19, 24, 28],
#         [19, 24, 28],
#         [19, 24, 28]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (1038, 1600, 3)

# %% [markdown]
# ### Skimage

# %% [markdown]
#  pip install scikit-image

# %%
from skimage import io

# %%
img = io.imread('./Virat.jpg')

# %%
print(img)
# Out:
# [[[32 47 52]
#   [32 47 52]
#   [32 47 52]
#   ...
#   [38 57 64]
#   [38 57 64]
#   [38 57 64]]
#
#  [[32 47 52]
#   [32 47 52]
#   [32 47 52]
#   ...
#   [38 57 64]
#   [38 57 64]
#   [38 57 64]]
#
#  [[33 48 53]
#   [33 48 53]
#   [33 48 53]
#   ...
#   [38 57 64]
#   [37 56 63]
#   [37 56 63]]
#
#  ...
#
#  [[15 20 26]
#   [15 20 26]
#   [15 20 26]
#   ...
#   [19 24 28]
#   [19 24 28]
#   [19 24 28]]
#
#  [[15 20 26]
#   [15 20 26]
#   [15 20 26]
#   ...
#   [19 24 28]
#   [19 24 28]
#   [19 24 28]]
#
#  [[15 20 26]
#   [15 20 26]
#   [15 20 26]
#   ...
#   [19 24 28]
#   [19 24 28]
#   [19 24 28]]]

# %%
plt.imshow(img)

# %% [markdown]
# ### CV2
# pip install opencv-python

# %%
import cv2

# %%
img = cv2.imread('./Virat.jpg')
img
# Out:
# array([[[52, 47, 32],
#         [52, 47, 32],
#         [52, 47, 32],
#         ...,
#         [64, 57, 38],
#         [64, 57, 38],
#         [64, 57, 38]],
#
#        [[52, 47, 32],
#         [52, 47, 32],
#         [52, 47, 32],
#         ...,
#         [64, 57, 38],
#         [64, 57, 38],
#         [64, 57, 38]],
#
#        [[53, 48, 33],
#         [53, 48, 33],
#         [53, 48, 33],
#         ...,
#         [64, 57, 38],
#         [63, 56, 37],
#         [63, 56, 37]],
#
#        ...,
#
#        [[26, 20, 15],
#         [26, 20, 15],
#         [26, 20, 15],
#         ...,
#         [28, 24, 19],
#         [28, 24, 19],
#         [28, 24, 19]],
#
#        [[26, 20, 15],
#         [26, 20, 15],
#         [26, 20, 15],
#         ...,
#         [28, 24, 19],
#         [28, 24, 19],
#         [28, 24, 19]],
#
#        [[26, 20, 15],
#         [26, 20, 15],
#         [26, 20, 15],
#         ...,
#         [28, 24, 19],
#         [28, 24, 19],
#         [28, 24, 19]]], dtype=uint8)

# %%
plt.imshow(img) # CV2 READS IMAGE AS BGR

# %%
plt.imshow(img[:,:,::-1])

# %%
cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
